# %% [markdown]
# <a href="https://colab.research.google.com/github/ashikha-03/Pandas_workout/blob/main/L1_and_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Low variance and low bias - Perfect
# Low variance and high bias - Underfitting
# High variance and Low bias - Overfitting
#
# RIDGE REGRESSION FORMULA :(Circle shape)
# It will never come (bcoz we square the values) to zero but it can come closer to zero
# https://images.datacamp.com/image/upload/f_auto,q_auto:best/v1543418448/eq10_h59azt.png
#
# LASSO REGRESSION FORMULA:(Diamond Shape)
# As we take modulus (absolute value) lasso reach to zero
# https://images.datacamp.com/image/upload/f_auto,q_auto:best/v1543418448/eq11_ij4mms.png
# Minimization objective = LS Obj + α * (sum of the absolute value of coefficients)
#
# Diagram:
# https://images.datacamp.com/image/upload/v1648205672/image18_a3zz7y.png

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([2.1,3.8,6.5,9.2,11.2])

# %%
x_b=np.c_[np.ones((x.shape[0],1)),x]
x_b
# Out:
# array([[1., 1.],
#        [1., 2.],
#        [1., 3.],
#        [1., 4.],
#        [1., 5.]])

# %%
alpha_ridge=1.0
alpha_lasso=0.1
num_iterations=1000
learning_rate=0.01

# %%
def lasso_regression(x,y,alpha,num_iterations,learning_rate):
  m,n=x.shape
  theta=np.zeros(n)
  for _ in range(num_iterations):
    y_pred=x.dot(theta)
    gradient=(x.T.dot(y_pred - y)+alpha*np.sign(theta))/m
    theta-=learning_rate*gradient
  return theta #theta=weight

# %%
def ridge_regression(x,y,alpha,num_iterations,learning_rate):
  m,n=x.shape
  theta=np.zeros(n)
  for _ in range(num_iterations):
    y_pred=x.dot(theta)
    gradient=(x.T.dot(y_pred - y)+alpha*theta)/m
    theta-=learning_rate*gradient
  return theta #theta=weight

# %%
theta_ridge=ridge_regression(x_b,y,alpha_ridge,num_iterations,learning_rate)
theta_lasso=lasso_regression(x_b,y,alpha_lasso,num_iterations,learning_rate)

# %%
plt.scatter(x,y,label='Data')
plt.plot(x,x_b.dot(theta_ridge),label=f'Rifge(L2) Regression',color='green')
plt.plot(x,x_b.dot(theta_lasso),label=f'Lasso(L1) Regression',color='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
